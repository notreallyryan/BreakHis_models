# %% [markdown]
# # Training the Classification Models

# %%
from lib import dataLoader
from lib import model_eval
from lib import models
from torch.utils.tensorboard import SummaryWriter
import torch
import torchvision
import os
from inspect import getmembers, isclass

from torch.nn import CrossEntropyLoss
from torch.optim import Adam

# %% [markdown]
# First, initiate the variables common to all models. In this case they will all use the same training dataloader object and device.

# %%
#getting training dataloader and setting device to GPU
path = "C:/Users/Ryan/.cache/BreaKHis_split/train"
train = dataLoader.make_dataloader(path, train = True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Then, train each model in the model.py file.
# Each model training will need it's own optimizer, as Adam will take different model parameters for each one.
# For each model, training metrics can be seen in real time by using *tensorboard --logdirs=summary_writers/MODEL_NAME* in console, though epoch results will also be printed by the function.

# %%
#loss function is the same for all
loss_fxn = CrossEntropyLoss()

#get list of models
model_list = getmembers(models, isclass)
print(model_list)
# Out:
# [('DenseNet_model', <class 'lib.models.DenseNet_model'>), ('MobileNet_model', <class 'lib.models.MobileNet_model'>), ('ResNet_model', <class 'lib.models.ResNet_model'>), ('VGG_model', <class 'lib.models.VGG_model'>)]

# %% [markdown]
# It's best to train each model seperately, instead of all at once.
# That way, if one model fails for some reason, not all of them need to be retrained.
# (I may or may not have learned this the hard way.)

# %%
def run_train_fxn(m):
    writer = SummaryWriter(log_dir="summary_writers/" + m[0])
    model = m[1]()
    optimizer = Adam(model.parameters())
    model_eval.train_model(model, m[0], train, writer, loss_fxn, optimizer, device, epochs = 25)

# %% [markdown]
# ### Training DenseNet model

# %%
run_train_fxn(model_list[0])
# Out:
# Training DenseNet_model:
# Epoch: 1
# Training Accuracy: 0.6497838171710932
# Training Precision: 0.6893203883495146
# Training Recall: 0.8930817610062893
# Training F1: 0.7780821917808219
#
#
# Epoch: 2
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 3
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 4
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 5
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 6
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 7
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 8
# Training Accuracy: 0.7510809141445337
# Training Precision: 0.7441540577716643
# Training Recall: 0.97214734950584
# Training F1: 0.8430074016361512
#
#
# Epoch: 9
# Training Accuracy: 0.8437306979617047
# Training Precision: 0.9011194029850746
# Training Recall: 0.8679245283018868
# Training F1: 0.8842105263157894
#
#
# Epoch: 10
# Training Accuracy: 0.8412600370599135
# Training Precision: 0.8440514469453376
# Training Recall: 0.9433962264150944
# Training F1: 0.8909630886720408
#
#
# Epoch: 11
# Training Accuracy: 0.871525633106856
# Training Precision: 0.8818565400843882
# Training Recall: 0.9389038634321654
# Training F1: 0.9094865100087032
#
#
# Epoch: 12
# Training Accuracy: 0.8517603458925262
# Training Precision: 0.8832309043020193
# Training Recall: 0.903863432165319
# Training F1: 0.8934280639431617
#
#
# Epoch: 13
# Training Accuracy: 0.8289067325509574
# Training Precision: 0.8603448275862069
# Training Recall: 0.8966756513926325
# Training F1: 0.8781346238451386
#
#
# Epoch: 14
# Training Accuracy: 0.8486720197652872
# Training Precision: 0.868421052631579
# Training Recall: 0.9191374663072777
# Training F1: 0.8930597992143169
#
#
# Epoch: 15
# Training Accuracy: 0.8597899938233478
# Training Precision: 0.8601626016260162
# Training Recall: 0.9505840071877808
# Training F1: 0.903115663679044
#
#
# Epoch: 16
# Training Accuracy: 0.8758492896849908
# Training Precision: 0.9191176470588235
# Training Recall: 0.8984725965858041
# Training F1: 0.9086778736937755
#
#
# Epoch: 17
# Training Accuracy: 0.8665843113032736
# Training Precision: 0.8608205953338697
# Training Recall: 0.9613656783468104
# Training F1: 0.9083191850594228
#
#
# Epoch: 18
# Training Accuracy: 0.8758492896849908
# Training Precision: 0.8756177924217463
# Training Recall: 0.9550763701707098
# Training F1: 0.913622690159003
#
#
# Epoch: 19
# Training Accuracy: 0.8826436071649166
# Training Precision: 0.9051799824407375
# Training Recall: 0.9263252470799641
# Training F1: 0.9156305506216696
#
#
# Epoch: 20
# Training Accuracy: 0.8764669549104386
# Training Precision: 0.8945548833189283
# Training Recall: 0.9299191374663073
# Training F1: 0.9118942731277533
#
#
# Epoch: 21
# Training Accuracy: 0.8807906114885732
# Training Precision: 0.8776683087027914
# Training Recall: 0.9604672057502246
# Training F1: 0.9172029172029172
#
#
# Epoch: 22
# Training Accuracy: 0.8789376158122297
# Training Precision: 0.9171974522292994
# Training Recall: 0.9056603773584906
# Training F1: 0.9113924050632911
#
#
# Epoch: 23
# Training Accuracy: 0.8949969116738727
# Training Precision: 0.9139596136962248
# Training Recall: 0.9353099730458221
# Training F1: 0.9245115452930728
#
#
# Epoch: 24
# Training Accuracy: 0.875231624459543
# Training Precision: 0.9048888888888889
# Training Recall: 0.9146451033243486
# Training F1: 0.9097408400357462
#
#
# Epoch: 25
# Training Accuracy: 0.8968499073502162
# Training Precision: 0.8994932432432432
# Training Recall: 0.9568733153638814
# Training F1: 0.9272964736612973

# %% [markdown]
# ### Training MobileNet model

# %%
run_train_fxn(model_list[1])
# Out:
# Training MobileNet_model:
# Epoch: 1
# Training Accuracy: 0.6757257566399012
# Training Precision: 0.6870229007633588
# Training Recall: 0.9703504043126685
# Training F1: 0.8044692737430168
#
#
# Epoch: 2
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 3
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 4
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 5
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 6
# Training Accuracy: 0.6886967263743051
# Training Precision: 0.6911487758945386
# Training Recall: 0.9892183288409704
# Training F1: 0.8137472283813747
#
#
# Epoch: 7
# Training Accuracy: 0.8684373069796171
# Training Precision: 0.8926701570680629
# Training Recall: 0.9191374663072777
# Training F1: 0.9057104913678619
#
#
# Epoch: 8
# Training Accuracy: 0.8616429894996912
# Training Precision: 0.9037238873751136
# Training Recall: 0.8939802336028752
# Training F1: 0.8988256549232159
#
#
# Epoch: 9
# Training Accuracy: 0.8672019765287214
# Training Precision: 0.8870689655172413
# Training Recall: 0.9245283018867925
# Training F1: 0.9054113506379234
#
#
# Epoch: 10
# Training Accuracy: 0.8529956763434219
# Training Precision: 0.8606760098928277
# Training Recall: 0.9380053908355795
# Training F1: 0.8976784178847808
#
#
# Epoch: 11
# Training Accuracy: 0.8807906114885732
# Training Precision: 0.9028021015761821
# Training Recall: 0.9263252470799641
# Training F1: 0.9144124168514413
#
#
# Epoch: 12
# Training Accuracy: 0.8758492896849908
# Training Precision: 0.9042553191489362
# Training Recall: 0.9164420485175202
# Training F1: 0.9103078982597055
#
#
# Epoch: 13
# Training Accuracy: 0.8931439159975293
# Training Precision: 0.9010238907849829
# Training Recall: 0.9487870619946092
# Training F1: 0.9242888402625821
#
#
# Epoch: 14
# Training Accuracy: 0.8906732550957381
# Training Precision: 0.8986371379897785
# Training Recall: 0.9478885893980233
# Training F1: 0.9226060341058154
#
#
# Epoch: 15
# Training Accuracy: 0.8795552810376775
# Training Precision: 0.9346590909090909
# Training Recall: 0.8867924528301887
# Training F1: 0.9100968188105117
#
#
# Epoch: 16
# Training Accuracy: 0.8795552810376775
# Training Precision: 0.8923076923076924
# Training Recall: 0.9380053908355795
# Training F1: 0.9145860709592641
#
#
# Epoch: 17
# Training Accuracy: 0.8641136504014824
# Training Precision: 0.8832618025751073
# Training Recall: 0.9245283018867925
# Training F1: 0.9034240561896401
#
#
# Epoch: 18
# Training Accuracy: 0.8739962940086473
# Training Precision: 0.8621513944223107
# Training Recall: 0.97214734950584
# Training F1: 0.9138513513513513
#
#
# Epoch: 19
# Training Accuracy: 0.8684373069796171
# Training Precision: 0.8623188405797102
# Training Recall: 0.9622641509433962
# Training F1: 0.9095541401273886
#
#
# Epoch: 20
# Training Accuracy: 0.8739962940086473
# Training Precision: 0.9054415700267618
# Training Recall: 0.9119496855345912
# Training F1: 0.9086839749328559
#
#
# Epoch: 21
# Training Accuracy: 0.8764669549104386
# Training Precision: 0.8959236773633998
# Training Recall: 0.9281221922731356
# Training F1: 0.911738746690203
#
#
# Epoch: 22
# Training Accuracy: 0.8548486720197653
# Training Precision: 0.839258114374034
# Training Recall: 0.9757412398921833
# Training F1: 0.9023680930619028
#
#
# Epoch: 23
# Training Accuracy: 0.8820259419394688
# Training Precision: 0.893344709897611
# Training Recall: 0.9407008086253369
# Training F1: 0.9164113785557987
#
#
# Epoch: 24
# Training Accuracy: 0.8869672637430512
# Training Precision: 0.9050522648083623
# Training Recall: 0.9335130278526504
# Training F1: 0.91906236178682
#
#
# Epoch: 25
# Training Accuracy: 0.8634959851760345
# Training Precision: 0.9223484848484849
# Training Recall: 0.8751123090745733
# Training F1: 0.8981097279852467

# %% [markdown]
# ### Training ResNet model

# %%
run_train_fxn(model_list[2])
# Out:
# Training ResNet_model:
# Epoch: 1
# Training Accuracy: 0.6695491043854231
# Training Precision: 0.6960651289009498
# Training Recall: 0.921832884097035
# Training F1: 0.793196752995748
#
#
# Epoch: 2
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 3
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 4
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 5
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 6
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 7
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 8
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 9
# Training Accuracy: 0.830142063001853
# Training Precision: 0.8335987261146497
# Training Recall: 0.9407008086253369
# Training F1: 0.8839172646686365
#
#
# Epoch: 10
# Training Accuracy: 0.8227300802964793
# Training Precision: 0.861646234676007
# Training Recall: 0.8840970350404312
# Training F1: 0.8727272727272727
#
#
# Epoch: 11
# Training Accuracy: 0.8641136504014824
# Training Precision: 0.9040723981900453
# Training Recall: 0.8975741239892183
# Training F1: 0.9008115419296664
#
#
# Epoch: 12
# Training Accuracy: 0.8739962940086473
# Training Precision: 0.8894601542416453
# Training Recall: 0.9326145552560647
# Training F1: 0.9105263157894737
#
#
# Epoch: 13
# Training Accuracy: 0.8789376158122297
# Training Precision: 0.906832298136646
# Training Recall: 0.9182389937106918
# Training F1: 0.9125
#
#
# Epoch: 14
# Training Accuracy: 0.8993205682520075
# Training Precision: 0.8998316498316499
# Training Recall: 0.9604672057502246
# Training F1: 0.92916123424598
#
#
# Epoch: 15
# Training Accuracy: 0.8431130327362569
# Training Precision: 0.8987929433611885
# Training Recall: 0.8697214734950584
# Training F1: 0.8840182648401826
#
#
# Epoch: 16
# Training Accuracy: 0.8616429894996912
# Training Precision: 0.8670520231213873
# Training Recall: 0.9433962264150944
# Training F1: 0.9036144578313253
#
#
# Epoch: 17
# Training Accuracy: 0.8684373069796171
# Training Precision: 0.8813559322033898
# Training Recall: 0.9344115004492363
# Training F1: 0.907108591365024
#
#
# Epoch: 18
# Training Accuracy: 0.8851142680667079
# Training Precision: 0.8978540772532189
# Training Recall: 0.9398023360287511
# Training F1: 0.9183494293239683
#
#
# Epoch: 19
# Training Accuracy: 0.8888202594193947
# Training Precision: 0.8826907301066448
# Training Recall: 0.9667565139263252
# Training F1: 0.9228130360205832
#
#
# Epoch: 20
# Training Accuracy: 0.875231624459543
# Training Precision: 0.90999099909991
# Training Recall: 0.9083557951482479
# Training F1: 0.9091726618705036
#
#
# Epoch: 21
# Training Accuracy: 0.862260654725139
# Training Precision: 0.8758445945945946
# Training Recall: 0.9317160826594789
# Training F1: 0.9029168480626905
#
#
# Epoch: 22
# Training Accuracy: 0.891290920321186
# Training Precision: 0.892707460184409
# Training Recall: 0.9568733153638814
# Training F1: 0.9236773633998265
#
#
# Epoch: 23
# Training Accuracy: 0.8968499073502162
# Training Precision: 0.9163732394366197
# Training Recall: 0.9353099730458221
# Training F1: 0.9257447754557581
#
#
# Epoch: 24
# Training Accuracy: 0.8770846201358864
# Training Precision: 0.8685483870967742
# Training Recall: 0.967654986522911
# Training F1: 0.915427114322142
#
#
# Epoch: 25
# Training Accuracy: 0.8937615812229771
# Training Precision: 0.899067005937235
# Training Recall: 0.9523809523809523
# Training F1: 0.924956369982548

# %% [markdown]
# ### Training VGG model

# %%
run_train_fxn(model_list[3])
# Out:
# Training VGG_model:
# Epoch: 1
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 2
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 3
# Training Accuracy: 0.6874613959234095
# Training Precision: 0.6874613959234095
# Training Recall: 1.0
# Training F1: 0.8147877013177159
#
#
# Epoch: 4
# Training Accuracy: 0.7801111797405806
# Training Precision: 0.7843726521412472
# Training Recall: 0.9380053908355795
# Training F1: 0.8543371522094927
#
#
# Epoch: 5
# Training Accuracy: 0.8165534280420013
# Training Precision: 0.8469387755102041
# Training Recall: 0.894878706199461
# Training F1: 0.8702490170380078
#
#
# Epoch: 6
# Training Accuracy: 0.8214947498455837
# Training Precision: 0.8497453310696095
# Training Recall: 0.89937106918239
# Training F1: 0.8738542121344391
#
#
# Epoch: 7
# Training Accuracy: 0.8363187152563311
# Training Precision: 0.8509933774834437
# Training Recall: 0.9236298292902066
# Training F1: 0.8858250753985352
#
#
# Epoch: 8
# Training Accuracy: 0.8659666460778258
# Training Precision: 0.8758389261744967
# Training Recall: 0.9380053908355795
# Training F1: 0.9058568329718004
#
#
# Epoch: 9
# Training Accuracy: 0.8431130327362569
# Training Precision: 0.864910790144435
# Training Recall: 0.9146451033243486
# Training F1: 0.8890829694323145
#
#
# Epoch: 10
# Training Accuracy: 0.8523780111179741
# Training Precision: 0.8672268907563025
# Training Recall: 0.9272237196765498
# Training F1: 0.8962223187147199
#
#
# Epoch: 11
# Training Accuracy: 0.8252007411982706
# Training Precision: 0.839607201309329
# Training Recall: 0.921832884097035
# Training F1: 0.8788008565310492
#
#
# Epoch: 12
# Training Accuracy: 0.871525633106856
# Training Precision: 0.8767693588676103
# Training Recall: 0.9460916442048517
# Training F1: 0.9101123595505618
#
#
# Epoch: 13
# Training Accuracy: 0.8690549722050649
# Training Precision: 0.8808114961961115
# Training Recall: 0.9362084456424079
# Training F1: 0.9076655052264808
#
#
# Epoch: 14
# Training Accuracy: 0.8721432983323039
# Training Precision: 0.880672268907563
# Training Recall: 0.9415992812219227
# Training F1: 0.9101172383847156
#
#
# Epoch: 15
# Training Accuracy: 0.8709079678814082
# Training Precision: 0.8811129848229342
# Training Recall: 0.9389038634321654
# Training F1: 0.9090909090909091
#
#
# Epoch: 16
# Training Accuracy: 0.8690549722050649
# Training Precision: 0.8920800696257616
# Training Recall: 0.9209344115004492
# Training F1: 0.9062776304155614
#
#
# Epoch: 17
# Training Accuracy: 0.8789376158122297
# Training Precision: 0.8922155688622755
# Training Recall: 0.9371069182389937
# Training F1: 0.9141104294478528
#
#
# Epoch: 18
# Training Accuracy: 0.881408276714021
# Training Precision: 0.8892645815722738
# Training Recall: 0.945193171608266
# Training F1: 0.9163763066202091
#
#
# Epoch: 19
# Training Accuracy: 0.8943792464484249
# Training Precision: 0.904639175257732
# Training Recall: 0.9460916442048517
# Training F1: 0.924901185770751
#
#
# Epoch: 20
# Training Accuracy: 0.8672019765287214
# Training Precision: 0.8917975567190227
# Training Recall: 0.9182389937106918
# Training F1: 0.9048251438689686
#
#
# Epoch: 21
# Training Accuracy: 0.8702903026559605
# Training Precision: 0.8875536480686695
# Training Recall: 0.9290206648697215
# Training F1: 0.9078138718173837
#
#
# Epoch: 22
# Training Accuracy: 0.8770846201358864
# Training Precision: 0.8946459412780656
# Training Recall: 0.9308176100628931
# Training F1: 0.912373403786878
#
#
# Epoch: 23
# Training Accuracy: 0.8943792464484249
# Training Precision: 0.904639175257732
# Training Recall: 0.9460916442048517
# Training F1: 0.924901185770751
#
#
# Epoch: 24
# Training Accuracy: 0.8987029030265596
# Training Precision: 0.9101123595505618
# Training Recall: 0.9460916442048517
# Training F1: 0.9277533039647577
#
#
# Epoch: 25
# Training Accuracy: 0.8844966028412601
# Training Precision: 0.9033101045296167
# Training Recall: 0.9317160826594789
# Training F1: 0.9172932330827067
